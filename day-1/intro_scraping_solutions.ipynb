# %% [markdown]
# # Introduction to web-scraping: Solutions
#
#
# ## Outline
#
# * [Structured queries with APIs](#apis)
#     * [Google Fact Check API](#factapi)
# * [URL collection with automated Google search](#URLs)
#    * [Scraping school URLs](#school_URLs)
#    * [Scraping URLs using a blacklist](blacklist)
# * [Mirroring websites with `wget`](#wget)
#    * [Features of `wget`](#wget_features)
# * [Template code: See Google Places API in action](#Places)
#
# **__________________________________**

# %% [markdown]
# # Structured queries with APIs<a id='apis'></a>

# %% [markdown]
# ## Google Fact Check API<a id='factapi'></a>

# %%
# ONLY IF YOU HAVE API KEY: Get key from file
api_key_fp = '../extra/api_key.txt'
with open(api_key_fp) as keyfile:
    key = keyfile.read().strip()
    
# Import package for making web requests
import requests

# %%
# Define what to search for in API
query = 'infrastructure'

# Set backend URL for requesting data from API
search_url = "https://factchecktools.googleapis.com/v1alpha1/claims:search"

# Make data request (first page of results only)
response = requests.get(
    url=search_url, 
    params=dict(
        key=key, 
        languageCode='en-US', 
        query=query)).json()

# Show the result
print(response)
# Out:
# {'claims': [{'text': '“Each job created in Biden’s ‘infrastructure plan’ will cost the American people $850,000.”', 'claimant': 'Republican National Committee', 'claimDate': '2021-04-20T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/21/faulty-math-claim-that-bidens-infrastructure-plan-costs-850000-per-job/', 'title': "Analysis | Faulty math: The claim that Biden's infrastructure plan ...", 'textualRating': 'Three Pinocchios', 'languageCode': 'en'}]}, {'text': 'Infrastructure only comprises of roads and bridges.', 'claimant': 'Leader McConnell', 'claimDate': '2021-04-03T02:33:00Z', 'claimReview': [{'publisher': {'site': 'misbar.com'}, 'url': 'https://misbar.com/en/factcheck/2021/04/03/infrastructure-is-more-than-roads-and-bridges', 'title': 'Infrastructure is More than Roads and Bridges | Misbar', 'reviewDate': '2021-04-03T02:33:00Z', 'textualRating': 'Fake', 'languageCode': 'en'}]}, {'text': '“These figures are what you would consider regular appropriations-plus. So it’s baseline-plus.”', 'claimant': 'Shelley Moore Capito', 'claimDate': '2021-04-22T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/26/apples-apples-senate-gop-infrastructure-proposal-is-smaller-than-it-appears/', 'title': 'Analysis | Apples to apples, the Senate GOP infrastructure proposal ...', 'textualRating': 'Correct', 'languageCode': 'en'}]}, {'text': 'Says Joe Biden’s infrastructure plan “is the Green New Deal.”', 'claimant': 'Citizens United', 'claimDate': '2021-03-31T00:00:00Z', 'claimReview': [{'publisher': {'name': 'PolitiFact', 'site': 'politifact.com'}, 'url': 'https://www.politifact.com/factchecks/2021/apr/02/citizens-united/citizens-united-calls-bidens-infrastructure-plan-g/', 'title': "Citizens United calls Biden's infrastructure plan the Green New Deal ...", 'textualRating': 'Mostly False', 'languageCode': 'en'}]}, {'text': 'There was no public infrastructure built during the Benigno “Noynoy” Aquino III administration.', 'claimReview': [{'publisher': {'name': 'Rappler', 'site': 'rappler.com'}, 'url': 'https://www.rappler.com/newsbreak/fact-check/no-infrastructure-built-under-noynoy-aquino', 'title': 'FALSE: No infrastructure built under Noynoy Aquino', 'reviewDate': '2021-03-30T06:19:28Z', 'textualRating': 'False', 'languageCode': 'en'}]}, {'text': '“Only about 6% of the president’s proposal actually goes" to infrastructure, meaning "water, wastewater ... highways, roads, bridges, perhaps broadband.”', 'claimant': 'John Thune', 'claimDate': '2021-04-11T00:00:00Z', 'claimReview': [{'publisher': {'name': 'FactCheck.org', 'site': 'factcheck.org'}, 'url': 'https://www.factcheck.org/2021/04/underselling-the-infrastructure-in-infrastructure-plan/', 'title': 'Underselling the Infrastructure in Infrastructure Plan', 'textualRating': '6% is too low', 'languageCode': 'en'}]}, {'text': '“The proposed tax increases in the Biden administration’s infrastructure plan could lead to 1 million fewer jobs in the first two years.”', 'claimant': 'Roy Blunt', 'claimDate': '2021-04-13T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/14/pair-misleading-gop-attacks-bidens-infrastructure-plan/', 'title': "Analysis | A pair of misleading GOP attacks on Biden's infrastructure ...", 'reviewDate': '2021-04-14T12:49:17Z', 'textualRating': 'Mostly False', 'languageCode': 'en'}]}, {'text': '“This is a massive social welfare spending program combined with a massive tax increase on small-business job creators.”', 'claimant': 'Roger Wicker', 'claimDate': '2021-04-11T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/14/pair-misleading-gop-atta ...

# %% [markdown]
# Notice that the claim reviews in the query response sometimes include `claimDate` and `claimant`, but they _always_ include these keys:
# ```
# text, claimReview[publisher[name, site], url, title, textualRating]
# ```
# Where `text` is the claim (often wrong), `publisher` is the fact checking site (e.g., Snopes), and `textualRating` is the fact checker's evaluation of the claim (e.g., 'Mostly True', 'Pants on Fire', 'Two Pinocchios').

# %% [markdown]
# ## Challenge

# %% [markdown]
# Show the `claimant`, `text`, `claimDate`, and `textualRating` features--_when available_--for first 10 claims in the API response. I've copied the raw response output below for you to play with.<br/>
# _Hint:_ `claimReview` is a list data type. How do you need to call the list to access the dictionary within it?

# %%
response = {'claims': [{'text': '“Each job created in Biden’s ‘infrastructure plan’ will cost the American people $850,000.”', 'claimant': 'Republican National Committee', 'claimDate': '2021-04-20T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/21/faulty-math-claim-that-bidens-infrastructure-plan-costs-850000-per-job/', 'title': "Analysis | Faulty math: The claim that Biden's infrastructure plan ...", 'textualRating': 'Three Pinocchios', 'languageCode': 'en'}]}, {'text': 'Infrastructure only comprises of roads and bridges.', 'claimant': 'Leader McConnell', 'claimDate': '2021-04-03T02:33:00Z', 'claimReview': [{'publisher': {'site': 'misbar.com'}, 'url': 'https://misbar.com/en/factcheck/2021/04/03/infrastructure-is-more-than-roads-and-bridges', 'title': 'Infrastructure is More than Roads and Bridges | Misbar', 'reviewDate': '2021-04-03T02:33:00Z', 'textualRating': 'Fake', 'languageCode': 'en'}]}, {'text': '“These figures are what you would consider regular appropriations-plus. So it’s baseline-plus.”', 'claimant': 'Shelley Moore Capito', 'claimDate': '2021-04-22T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/26/apples-apples-senate-gop-infrastructure-proposal-is-smaller-than-it-appears/', 'title': 'Analysis | Apples to apples, the Senate GOP infrastructure proposal ...', 'textualRating': 'Correct', 'languageCode': 'en'}]}, {'text': 'Says Joe Biden’s infrastructure plan “is the Green New Deal.”', 'claimant': 'Citizens United', 'claimDate': '2021-03-31T00:00:00Z', 'claimReview': [{'publisher': {'name': 'PolitiFact', 'site': 'politifact.com'}, 'url': 'https://www.politifact.com/factchecks/2021/apr/02/citizens-united/citizens-united-calls-bidens-infrastructure-plan-g/', 'title': "Citizens United calls Biden's infrastructure plan the Green New Deal ...", 'textualRating': 'Mostly False', 'languageCode': 'en'}]}, {'text': 'There was no public infrastructure built during the Benigno “Noynoy” Aquino III administration.', 'claimReview': [{'publisher': {'name': 'Rappler', 'site': 'rappler.com'}, 'url': 'https://www.rappler.com/newsbreak/fact-check/no-infrastructure-built-under-noynoy-aquino', 'title': 'FALSE: No infrastructure built under Noynoy Aquino', 'reviewDate': '2021-03-30T06:19:28Z', 'textualRating': 'False', 'languageCode': 'en'}]}, {'text': '“Only about 6% of the president’s proposal actually goes" to infrastructure, meaning "water, wastewater ... highways, roads, bridges, perhaps broadband.”', 'claimant': 'John Thune', 'claimDate': '2021-04-11T00:00:00Z', 'claimReview': [{'publisher': {'name': 'FactCheck.org', 'site': 'factcheck.org'}, 'url': 'https://www.factcheck.org/2021/04/underselling-the-infrastructure-in-infrastructure-plan/', 'title': 'Underselling the Infrastructure in Infrastructure Plan', 'textualRating': '6% is too low', 'languageCode': 'en'}]}, {'text': '“The proposed tax increases in the Biden administration’s infrastructure plan could lead to 1 million fewer jobs in the first two years.”', 'claimant': 'Roy Blunt', 'claimDate': '2021-04-13T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/14/pair-misleading-gop-attacks-bidens-infrastructure-plan/', 'title': "Analysis | A pair of misleading GOP attacks on Biden's infrastructure ...", 'reviewDate': '2021-04-14T12:49:17Z', 'textualRating': 'Mostly False', 'languageCode': 'en'}]}, {'text': '“This is a massive social welfare spending program combined with a massive tax increase on small-business job creators.”', 'claimant': 'Roger Wicker', 'claimDate': '2021-04-11T00:00:00Z', 'claimReview': [{'publisher': {'name': 'The Washington Post', 'site': 'washingtonpost.com'}, 'url': 'https://www.washingtonpost.com/politics/2021/04/14/pair-misleading-gop-attacks-bidens-infrastructure-plan/', 'title': "Analysis | A pair of misleading GOP attacks on Biden's infrastructure ...", 'reviewDate': '2021-04-14T12:49:17Z', 'textualRating': 'Three Pinocchios', 'languageCode': 'en'}]}, {'text': '“Something less than 6% ... of this proposal that President Biden has put forward is actually focused on infrastructure.”', 'claimant': 'Liz Cheney', 'claimDate': '2021-04-11T00:00:00Z', 'claimReview': [{'publisher': {'name': 'PolitiFact', 'site': 'politifact.com'}, 'url': 'https://www.politifact.com/factchecks/2021/apr/13/liz-cheney/liz-cheneys-dubious-claim-just-6-biden-plan-infras/', 'title': "Liz Cheney's dubious claim that just 6% of Biden plan is ...", 'textualRating': 'Pants on Fire', 'languageCode': 'en'}]}, {'text': 'President Joe Biden’s infrastructure proposal “is fully paid for. Across 15 years, it would raise all of the revenue needed for these once-in-a-lifetime investments."', 'claimant': 'Pete Buttigieg', 'claimDate': '2021-04-04T00:00:00Z', 'claimReview': [{'publisher': {'name': 'PolitiFact', 'site': 'politifact.com'}, 'url': 'https://www.politifact.com/factchecks/2021/apr/07/pete-buttigieg/joe-bidens-infrastructure-bill-fully-paid/', 'title': "Is Joe Biden's infrastructure proposal fully paid for?", 'textualRating': 'Mostly True', 'languageCode': 'en'}]}], 'nextPageToken': 'CAo'}

# %%
# Solution

for claim in response['claims'][:10]:
    if 'claimant' in claim and 'claimDate' in claim:
        print(f"Claim by {claim['claimant']} on {claim['claimDate']}, rated {claim['claimReview'][0]['textualRating']}: \n{claim['text']}")
    else:
        print(f"Claim rated {claim['claimReview'][0]['textualRating']}: \n{claim['text']}")
    print()
# Out:
# Claim by Republican National Committee on 2021-04-20T00:00:00Z, rated Three Pinocchios:
# “Each job created in Biden’s ‘infrastructure plan’ will cost the American people $850,000.”
#
# Claim by Leader McConnell on 2021-04-03T02:33:00Z, rated Fake:
# Infrastructure only comprises of roads and bridges.
#
# Claim by Shelley Moore Capito on 2021-04-22T00:00:00Z, rated Correct:
# “These figures are what you would consider regular appropriations-plus. So it’s baseline-plus.”
#
# Claim by Citizens United on 2021-03-31T00:00:00Z, rated Mostly False:
# Says Joe Biden’s infrastructure plan “is the Green New Deal.”
#
# Claim rated False:
# There was no public infrastructure built during the Benigno “Noynoy” Aquino III administration.
#
# Claim by John Thune on 2021-04-11T00:00:00Z, rated 6% is too low:
# “Only about 6% of the president’s proposal actually goes" to infrastructure, meaning "water, wastewater ... highways, roads, bridges, perhaps broadband.”
#
# Claim by Roy Blunt on 2021-04-13T00:00:00Z, rated Mostly False:
# “The proposed tax increases in the Biden administration’s infrastructure plan could lead to 1 million fewer jobs in the first two years.”
#
# Claim by Roger Wicker on 2021-04-11T00:00:00Z, rated Three Pinocchios:
# “This is a massive social welfare spending program combined with a massive tax increase on small-business job creators.”
#
# Claim by Liz Cheney on 2021-04-11T00:00:00Z, rated Pants on Fire:
# “Something less than 6% ... of this proposal that President Biden has put forward is actually focused on infrastructure.”
#
# Claim by Pete Buttigieg on 2021-04-04T00:00:00Z, rated Mostly True:
# President Joe Biden’s infrastructure proposal “is fully paid for. Across 15 years, it would raise all of the revenue needed for these once-in-a-lifetime investments."

# %% [markdown]
# # URL collection with automated Google search<a id='URLs'></a>

# %% [markdown]
# ## Scraping school URLs<a id='school_URLs'></a>

# %%
# Import automated Google search package
from googlesearch import search

# Define metadata for a single entity: a DC charter school
school_name = 'Capital City Public Charter School'
school_address = '100 Peabody Street NW, Washington, DC 20011'

# Search for first 10 Google results using joined metadata, show each one
for url in search(school_name + ' ' + school_address, \
                  stop=10, pause=5.0):
    print(url)
# Out:
# https://www.ccpcs.org/
# https://www.ccpcs.org/current-families/calendar
# https://www.ccpcs.org/about/mission-and-history
# https://www.ccpcs.org/admissions/applying-capital-city
# https://www.ccpcs.org/program/el-education
# https://www.ccpcs.org/about/our-staff
# https://www.greatschools.org/washington-dc/washington/282-Capital-City-PCS---Lower-School/
# https://www.facebook.com/CapitalCityPCS/
# https://www.niche.com/k12/capital-city-public-charter-school-washington-dc/
# https://www.niche.com/k12/capital-city-public-charter-school-middle-school-washington-dc/

# %% [markdown]
# ### Challenge

# %% [markdown]
# Collect the first 10 results from Google for Dr. David C. Walker Intermediate School located at 6500 Ih 35 N Ste C, San Antonio, TX 78218. What do you notice about the results? How do they compare to the previous set of results?

# %%
# Solution

# Define metadata
school_name = 'Dr. David C. Walker Intermediate School'
school_address = '6500 Ih 35 N Ste C, San Antonio, TX 78218'

# Automated search
for url in search(school_name + ' ' + school_address, \
                  stop=10, pause=5.0):
    print(url)
# Out:
# https://www.niche.com/k12/dr-david-c-walker-intermediate-school-san-antonio-tx/
# https://www.har.com/school/015806106/dr-david-c-walker-elementary-school
# https://www.greatschools.org/texas/san-antonio/12035-Dr-David-C-Walker-Intermediate-School/
# https://www.usnews.com/education/k12/texas/dr-david-c-walker-el-206298
# https://www.publicschoolreview.com/dr-david-c-walker-elementary-school-profile
# https://www.excellence-sa.org/walker
# https://nces.ed.gov/ccd/schoolsearch/school_detail.asp?ID=480006211404
# https://www.schooldigger.com/go/TX/schools/0006211404/school.aspx
# https://elementaryschools.org/directory/tx/cities/san-antonio/dr-david-c-walker-elementary/480006211404/
# https://closelocation.com/find-school/dr-david-c-walker-elementary-school-school-in-basse-basse-16-11508-1216-80

# %% [markdown]
# These results are much less clear and organized: Each one points to a different site, and all of them are third parties. Interestingly, the [first result](https://www.niche.com/k12/dr-david-c-walker-intermediate-school-san-antonio-tx/) (with domain of https://www.niche.com) does point to the [official website](https://excellence-sa.org/walker/), but extracting this information systematically would mean web-scraping--which we will get to tomorrow!

# %% [markdown]
# ## Scraping URLs using a blacklist<a id='blacklist'></a>

# %%
# Define blacklisted domains to filter out: third-party domains/false positives that we DON'T want to scrape 
blacklist = ['facebook.com', 'greatschools.org', 'niche.com', 'har.com', 'usnews.com', 'publicschoolreview.com', 
             'nces.ed.gov', 'dnb.com', 'schooldigger.com', 'elementaryschools.org', 'closelocation.com']

# Define search metadata
school_name = 'Dr. David C. Walker Intermediate School'
school_address = '6500 Ih 35 N Ste C, San Antonio, TX 78218'
#school_name = "River City Scholars Charter Academy"
#school_address = "944 Evergreen Street, Grand Rapids, MI 49507"

# Collect search results
urls = search(school_name + ' ' + school_address, \
              stop=20, pause=5.0) # Expand search range to help avoid blacklisted domains
print("Successfully collected Google search results.")

# Initialize blacklist match counter: How many blacklisted domains has this search encountered?
blacklisted_num = 0 

# Loop through google search output to find first good result:
for url in urls:
    if any(domain in url for domain in blacklist):
        print(f'Bad site detected: {url}') 
        blacklisted_num += 1 # Add one to blacklist match counter
    else:
        good_url = url
        print("Success! URL obtained by Google search with " + str(blacklisted_num) + " bad URLs avoided.")
        break # Exit for loop after first good url is found
        
print(f'Quality URL: {good_url}')
# Out:
# Successfully collected Google search results.
# Bad site detected: https://www.niche.com/k12/dr-david-c-walker-intermediate-school-san-antonio-tx/
# Bad site detected: https://www.har.com/school/015806106/dr-david-c-walker-elementary-school
# Bad site detected: https://www.greatschools.org/texas/san-antonio/12035-Dr-David-C-Walker-Intermediate-School/
# Bad site detected: https://www.usnews.com/education/k12/texas/dr-david-c-walker-el-206298
# Bad site detected: https://www.publicschoolreview.com/dr-david-c-walker-elementary-school-profile
# Success! URL obtained by Google search with 5 bad URLs avoided.
# Quality URL: https://www.excellence-sa.org/walker

# %% [markdown]
# What do you think of [the "quality" URL we landed on](http://castro.tea.state.tx.us/charter_apps/content/downloads/Renewals/015806_2.pdf)? Looks like we need to expand our blacklist!
#
# ### Challenge
#
# Improve our automated searching to get the genuine URL of Dr. David C. Walker Intermediate School. <br/>
# _Hint_: You could try (A) adding more URLs to the blacklist OR (B) try a simple search but for more URLs.

# %%
# Solution

# Option A: Define expanded blacklist
blacklist = ['facebook.com', 'greatschools.org', 'niche.com', 'har.com', 'usnews.com', 'publicschoolreview.com', 
             'nces.ed.gov', 'dnb.com', 'schooldigger.com', 'elementaryschools.org', 'closelocation.com', 
             'castro.tea.state.tx.us']

# Collect search results
urls = search(school_name + ' ' + school_address, \
              stop=20, pause=5.0) # Expand search range to help avoid blacklisted domains
print("Successfully collected Google search results.")

# Initialize blacklist match counter
blacklisted_num = 0 

# Get first good search result:
for url in urls:
    if any(domain in url for domain in blacklist):
        print(f'Bad site detected: {url}') 
        blacklisted_num += 1 # Add one to blacklist match counter
    else:
        good_url = url
        print("Success! URL obtained by Google search with " + str(blacklisted_num) + " bad URLs avoided.")
        break # Exit for loop after first good url is found
        
print(f'Quality URL: {good_url}')
# Out:
# Successfully collected Google search results.
# Bad site detected: https://www.niche.com/k12/dr-david-c-walker-intermediate-school-san-antonio-tx/
# Bad site detected: https://www.har.com/school/015806106/dr-david-c-walker-elementary-school
# Bad site detected: https://www.greatschools.org/texas/san-antonio/12035-Dr-David-C-Walker-Intermediate-School/
# Bad site detected: https://www.usnews.com/education/k12/texas/dr-david-c-walker-el-206298
# Bad site detected: https://www.publicschoolreview.com/dr-david-c-walker-elementary-school-profile
# Success! URL obtained by Google search with 5 bad URLs avoided.
# Quality URL: https://www.excellence-sa.org/walker

# %%
# Option B: Expanded simple search
for url in search(school_name + ' ' + school_address, \
                  stop=20, pause=5.0, num=20): # Get first 20 results: stop at 20, and get 20 in first page of results
    print(url)
# Out:
# https://www.niche.com/k12/dr-david-c-walker-intermediate-school-san-antonio-tx/
# https://www.har.com/school/015806106/dr-david-c-walker-elementary-school
# https://www.greatschools.org/texas/san-antonio/12035-Dr-David-C-Walker-Intermediate-School/
# https://www.usnews.com/education/k12/texas/dr-david-c-walker-el-206298
# https://www.publicschoolreview.com/dr-david-c-walker-elementary-school-profile
# https://excellence-sa.org/walker/
# https://nces.ed.gov/ccd/schoolsearch/school_detail.asp?ID=480006211404
# https://www.schooldigger.com/go/TX/schools/0006211404/school.aspx
# https://elementaryschools.org/directory/tx/cities/san-antonio/dr-david-c-walker-elementary/480006211404/
# https://closelocation.com/find-school/dr-david-c-walker-elementary-school-school-in-basse-basse-16-11508-1216-80
# http://castro.tea.state.tx.us/charter_apps/content/downloads/Renewals/015806_2.pdf
# https://www.homesnap.com/schools/TX/San_Antonio/Dr_David_C_Walker_Intermediate_School
# https://texas.hometownlocator.com/schools/profiles,n,dr%20david%20c%20walker%20el,z,78218,t,pb,i,1115128.cfm
# https://www.hisawyer.com/listings/schools/126444-dr-david-c-walker-elementary
# https://rehold.com/San+Antonio+TX/CASTLE+VW/6518
# https://www.realtytrac.com/property/tx/san-antonio/78218/6500-n-interstate-35/209130397/
# https://www.sanantonio.gov/Portals/0/Files/health/News/RestaurantReports/RRAPRIL2017.xlsx?ver=2017-05-12-162100-603
# https://www.robin-rogers.com/schools.asp
# https://zerodown.com/explore/guide/texas/greater-san-antonio/bexar-county/san-antonio/78218/general-krueger
# http://plains.citysmart.info/place/219108611537382/Krueger-Middle-School-PTA

# %% [markdown]
# # Mirroring websites with `wget`<a id='wget'></a>

# %%
# !wget https://mccourt.georgetown.edu/research/mdi-news/
# Out:
# --2021-04-27 14:10:11--  https://mccourt.georgetown.edu/research/mdi-news/
# Resolving mccourt.georgetown.edu (mccourt.georgetown.edu)... 23.185.0.1, 2620:12a:8000::1, 2620:12a:8001::1
# Connecting to mccourt.georgetown.edu (mccourt.georgetown.edu)|23.185.0.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148325 (145K) [text/html]
# Saving to: ‘index.html’
#
# index.html          100%[===================>] 144.85K  --.-KB/s    in 0.03s
#
# 2021-04-27 14:10:12 (4.25 MB/s) - ‘index.html’ saved [148325/148325]

# %% [markdown]
# ## Features of `wget`<a id='wget_features'></a>
#
#
# ```shell
# --page-requisites             Grabs all of the linked resources necessary to render the page (images, CSS, javascript, etc.)
# --wait                        Pauses between downloads (in seconds)
# --tries=3                     Retries failed downloads 3 times
# --user-agent=Mozilla          Makes wget look like a Mozilla browser by masking its user agent
# --header="Accept:text/html"   Sends header with each HTML request, looks more browser-ish
# --no-check-certificate        Doesnt check authenticity of website server (use only with trusted websites!)
# --mirror                      Downloads a full website and makes available for local viewing
# --recursive                   Recursively downloads files and follows links
# --no-parent 		          Does not follow links above hierarchical level of input URL
# --convert-links 	          Turns links into local links as appropriate
# --accept                      Download only file suffixes in this list (e.g., .html)
# --execute robots=off          Turns off automatic robots.txt checking, preventing server privacy exclusions
# --random-wait                 Randomizes the defined wait period to between .5 and 1.5x that value
# --background		          For a huge download, put the download in background
# --spider                      Determines whether the remote file exist at the destination (mimics web spiders)
# --domains   		          Downloads only only PDF files from specific domains
# --user --password   		  Downloads files from password protected sites
# ```

# %%
# !wget --page-requisites --wait=2 --tries=3 --user-agent=Mozilla --header="Accept:text/html" --no-check-certificate \
    https://mccourt.georgetown.edu/research/mdi-news/
# Out:
# --2021-04-27 14:10:13--  https://mccourt.georgetown.edu/research/mdi-news/
# Resolving mccourt.georgetown.edu (mccourt.georgetown.edu)... 23.185.0.1, 2620:12a:8001::1, 2620:12a:8000::1
# Connecting to mccourt.georgetown.edu (mccourt.georgetown.edu)|23.185.0.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148325 (145K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/mdi-news/index.html’
#
# mccourt.georgetown. 100%[===================>] 144.85K  --.-KB/s    in 0.02s
#
# 2021-04-27 14:10:13 (6.83 MB/s) - ‘mccourt.georgetown.edu/research/mdi-news/index.html’ saved [148325/148325]
#
# Loading robots.txt; please ignore errors.
# --2021-04-27 14:10:15--  https://mccourt.georgetown.edu/robots.txt
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 116 [text/plain]
# Saving to: ‘mccourt.georgetown.edu/robots.txt’
#
# mccourt.georgetown. 100%[===================>]     116  --.-KB/s    in 0s
#
# 2021-04-27 14:10:15 (2.01 MB/s) - ‘mccourt.georgetown.edu/robots.txt’ saved [116/116]
#
# --2021-04-27 14:10:17--  https://mccourt.georgetown.edu/wp-content/plugins/gu-whnu-blocks/build/gu-whnu-blocks-frontend.css?ver=1619497174
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1146 (1.1K) [text/css]
# Saving to: ‘mccourt.georgetown.edu/wp-content/plugins/gu-whnu-blocks/build/gu-whnu-blocks-frontend.css?ver=1619497174’
#
# mccourt.georgetown. 100%[===================>]   1.12K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:17 (28.6 MB/s) - ‘mccourt.georgetown.edu/wp-content/plugins/gu-whnu-blocks/build/gu-whnu-blocks-frontend.css?ver=1619497174’ saved [1146/1146]
#
# --2021-04-27 14:10:19--  https://mccourt.georgetown.edu/wp-content/themes/georgetown-child/style.css?ver=1.0.322
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 353 [text/css]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown-child/style.css?ver=1.0.322’
#
# mccourt.georgetown. 100%[===================>]     353  --.-KB/s    in 0s
#
# 2021-04-27 14:10:19 (9.78 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown-child/style.css?ver=1.0.322’ saved [353/353]
#
# --2021-04-27 14:10:21--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/css/vendor/swiper.min.css?ver=1.0.322
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19800 (19K) [text/css]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/css/vendor/swiper.min.css?ver=1.0.322’
#
# mccourt.georgetown. 100%[===================>]  19.34K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:21 (64.5 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/css/vendor/swiper.min.css?ver=1.0.322’ saved [19800/19800]
#
# --2021-04-27 14:10:23--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/css/style.css?ver=1.0.322
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 485624 (474K) [text/css]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/css/style.css?ver=1.0.322’
#
# mccourt.georgetown. 100%[===================>] 474.24K  --.-KB/s    in 0.02s
#
# 2021-04-27 14:10:23 (27.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/css/style.css?ver=1.0.322’ saved [485624/485624]
#
# --2021-04-27 14:10:25--  https://mccourt.georgetown.edu/wp-content/plugins/duracelltomi-google-tag-manager/js/gtm4wp-form-move-tracker.js?ver=1.12.2
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1536 (1.5K) [application/x-javascript]
# Saving to: ‘mccourt.georgetown.edu/wp-content/plugins/duracelltomi-google-tag-manager/js/gtm4wp-form-move-tracker.js?ver=1.12.2’
#
# mccourt.georgetown. 100%[===================>]   1.50K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:25 (38.9 MB/s) - ‘mccourt.georgetown.edu/wp-content/plugins/duracelltomi-google-tag-manager/js/gtm4wp-form-move-tracker.js?ver=1.12.2’ saved [1536/1536]
#
# --2021-04-27 14:10:27--  https://mccourt.georgetown.edu/wp-content/uploads/fbrfg/favicon.ico
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10990 (11K) [image/x-icon]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/fbrfg/favicon.ico’
#
# mccourt.georgetown. 100%[===================>]  10.73K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:27 (73.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/fbrfg/favicon.ico’ saved [10990/10990]
#
# --2021-04-27 14:10:29--  https://mccourt.georgetown.edu/wp-content/uploads/2020/12/McCabe-Research-Header-1600x900.png
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2479950 (2.4M) [image/png]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/12/McCabe-Research-Header-1600x900.png’
#
# mccourt.georgetown. 100%[===================>]   2.36M  --.-KB/s    in 0.06s
#
# 2021-04-27 14:10:30 (36.6 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/12/McCabe-Research-Header-1600x900.png’ saved [2479950/2479950]
#
# --2021-04-27 14:10:32--  https://mccourt.georgetown.edu/wp-content/uploads/2020/06/scotus-1600x900.jpg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 232437 (227K) [image/jpeg]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/06/scotus-1600x900.jpg’
#
# mccourt.georgetown. 100%[===================>] 226.99K  --.-KB/s    in 0.003s
#
# 2021-04-27 14:10:32 (84.2 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/06/scotus-1600x900.jpg’ saved [232437/232437]
#
# --2021-04-27 14:10:34--  https://mccourt.georgetown.edu/wp-content/uploads/2020/10/STANCE-V2-1600x900.png
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 834035 (814K) [image/png]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/10/STANCE-V2-1600x900.png’
#
# mccourt.georgetown. 100%[===================>] 814.49K  --.-KB/s    in 0.02s
#
# 2021-04-27 14:10:34 (44.8 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/10/STANCE-V2-1600x900.png’ saved [834035/834035]
#
# --2021-04-27 14:10:36--  https://mccourt.georgetown.edu/wp-content/uploads/2020/09/0925misinformation-1600x900.jpg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 66032 (64K) [image/jpeg]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/09/0925misinformation-1600x900.jpg’
#
# mccourt.georgetown. 100%[===================>]  64.48K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:36 (163 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/09/0925misinformation-1600x900.jpg’ saved [66032/66032]
#
# --2021-04-27 14:10:38--  https://mccourt.georgetown.edu/wp-content/uploads/2020/02/DC-US-Capitol-pic-rawpixel-id-433912-e1580741921224-1600x900.jpg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126601 (124K) [image/jpeg]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/02/DC-US-Capitol-pic-rawpixel-id-433912-e1580741921224-1600x900.jpg’
#
# mccourt.georgetown. 100%[===================>] 123.63K  --.-KB/s    in 0.002s
#
# 2021-04-27 14:10:38 (77.2 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/02/DC-US-Capitol-pic-rawpixel-id-433912-e1580741921224-1600x900.jpg’ saved [126601/126601]
#
# --2021-04-27 14:10:40--  https://mccourt.georgetown.edu/wp-content/uploads/2020/07/houses-in-dc-1600x900.jpg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 180322 (176K) [image/jpeg]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/07/houses-in-dc-1600x900.jpg’
#
# mccourt.georgetown. 100%[===================>] 176.10K  --.-KB/s    in 0.002s
#
# 2021-04-27 14:10:40 (88.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/07/houses-in-dc-1600x900.jpg’ saved [180322/180322]
#
# --2021-04-27 14:10:42--  https://mccourt.georgetown.edu/wp-content/uploads/2020/05/us-capitol-building-dc-1600x900.png
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2372233 (2.3M) [image/png]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2020/05/us-capitol-building-dc-1600x900.png’
#
# mccourt.georgetown. 100%[===================>]   2.26M  --.-KB/s    in 0.04s
#
# 2021-04-27 14:10:42 (54.7 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2020/05/us-capitol-building-dc-1600x900.png’ saved [2372233/2372233]
#
# --2021-04-27 14:10:44--  https://mccourt.georgetown.edu/wp-content/uploads/2019/10/mdi.1-1600x900.jpg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 359987 (352K) [image/jpeg]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2019/10/mdi.1-1600x900.jpg’
#
# mccourt.georgetown. 100%[===================>] 351.55K  --.-KB/s    in 0.003s
#
# 2021-04-27 14:10:45 (104 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2019/10/mdi.1-1600x900.jpg’ saved [359987/359987]
#
# --2021-04-27 14:10:47--  https://mccourt.georgetown.edu/wp-content/uploads/2019/12/20191017-Protocol_0472-1-1600x900.jpg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90832 (89K) [image/jpeg]
# Saving to: ‘mccourt.georgetown.edu/wp-content/uploads/2019/12/20191017-Protocol_0472-1-1600x900.jpg’
#
# mccourt.georgetown. 100%[===================>]  88.70K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:10:47 (148 MB/s) - ‘mccourt.georgetown.edu/wp-content/uploads/2019/12/20191017-Protocol_0472-1-1600x900.jpg’ saved [90832/90832]
#
# --2021-04-27 14:10:49--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-vendor.min.js?ver=1.0.322
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 289030 (282K) [application/x-javascript]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-vendor.min.js?ver=1.0.322’
#
# mccourt.georgetown. 100%[===================>] 282.26K  --.-KB/s    in 0.003s
#
# 2021-04-27 14:10:49 (98.1 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-vendor.min.js?ver=1.0.322’ saved [289030/289030]
#
# --2021-04-27 14:10:51--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-scripts.min.js?ver=1.0.322
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36934 (36K) [application/x-javascript]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-scripts.min.js?ver=1.0.322’
#
# mccourt.georgetown. 100%[===================>]  36.07K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:51 (120 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-scripts.min.js?ver=1.0.322’ saved [36934/36934]
#
# --2021-04-27 14:10:53--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-scripts-child.min.js
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2148 (2.1K) [application/x-javascript]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-scripts-child.min.js’
#
# mccourt.georgetown. 100%[===================>]   2.10K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:53 (46.4 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/js/dist/gu-scripts-child.min.js’ saved [2148/2148]
#
# --2021-04-27 14:10:55--  https://mccourt.georgetown.edu/wp-content/plugins/page-links-to/dist/new-tab.js?ver=3.3.5
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24734 (24K) [application/x-javascript]
# Saving to: ‘mccourt.georgetown.edu/wp-content/plugins/page-links-to/dist/new-tab.js?ver=3.3.5’
#
# mccourt.georgetown. 100%[===================>]  24.15K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:55 (124 MB/s) - ‘mccourt.georgetown.edu/wp-content/plugins/page-links-to/dist/new-tab.js?ver=3.3.5’ saved [24734/24734]
#
# --2021-04-27 14:10:57--  https://mccourt.georgetown.edu/wp-content/themes/georgetown-child/mccourt.css
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2648 (2.6K) [text/css]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown-child/mccourt.css’
#
# mccourt.georgetown. 100%[===================>]   2.59K  --.-KB/s    in 0s
#
# 2021-04-27 14:10:57 (64.4 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown-child/mccourt.css’ saved [2648/2648]
#
# --2021-04-27 14:10:59--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-search.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-search.svg’
#
# mccourt.georgetown. 100%[===================>]     674  --.-KB/s    in 0s
#
# 2021-04-27 14:10:59 (16.9 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-search.svg’ saved [674/674]
#
# --2021-04-27 14:11:01--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-search-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 651 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-search-white.svg’
#
# mccourt.georgetown. 100%[===================>]     651  --.-KB/s    in 0s
#
# 2021-04-27 14:11:01 (18.7 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-search-white.svg’ saved [651/651]
#
# --2021-04-27 14:11:03--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 569 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play.svg’
#
# mccourt.georgetown. 100%[===================>]     569  --.-KB/s    in 0s
#
# 2021-04-27 14:11:03 (16.6 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play.svg’ saved [569/569]
#
# --2021-04-27 14:11:05--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play-hover.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 569 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play-hover.svg’
#
# mccourt.georgetown. 100%[===================>]     569  --.-KB/s    in 0s
#
# 2021-04-27 14:11:05 (13.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play-hover.svg’ saved [569/569]
#
# --2021-04-27 14:11:07--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/seal.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 237835 (232K) [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/seal.svg’
#
# mccourt.georgetown. 100%[===================>] 232.26K  --.-KB/s    in 0.002s
#
# 2021-04-27 14:11:07 (134 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/seal.svg’ saved [237835/237835]
#
# --2021-04-27 14:11:09--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-swiper-arrow-left.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 464 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-swiper-arrow-left.svg’
#
# mccourt.georgetown. 100%[===================>]     464  --.-KB/s    in 0s
#
# 2021-04-27 14:11:09 (12.9 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-swiper-arrow-left.svg’ saved [464/464]
# --2021-04-27 14:11:11--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-swiper-arrow-right.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 462 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-swiper-arrow-right.svg’
#
# mccourt.georgetown. 100%[===================>]     462  --.-KB/s    in 0s
#
# 2021-04-27 14:11:11 (12.4 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-swiper-arrow-right.svg’ saved [462/462]
#
# --2021-04-27 14:11:13--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-chapters-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 945 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-chapters-white.svg’
#
# mccourt.georgetown. 100%[===================>]     945  --.-KB/s    in 0s
#
# 2021-04-27 14:11:13 (26.1 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-chapters-white.svg’ saved [945/945]
#
# --2021-04-27 14:11:15--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-close-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 521 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-close-white.svg’
#
# mccourt.georgetown. 100%[===================>]     521  --.-KB/s    in 0s
#
# 2021-04-27 14:11:15 (16.1 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-close-white.svg’ saved [521/521]
#
# --2021-04-27 14:11:17--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-down.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 462 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-down.svg’
#
# mccourt.georgetown. 100%[===================>]     462  --.-KB/s    in 0s
#
# 2021-04-27 14:11:17 (13.4 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-down.svg’ saved [462/462]
#
# --2021-04-27 14:11:19--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-up.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 464 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-up.svg’
#
# mccourt.georgetown. 100%[===================>]     464  --.-KB/s    in 0s
#
# 2021-04-27 14:11:19 (13.8 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-up.svg’ saved [464/464]
#
# --2021-04-27 14:11:21--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-filter-toggle.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1357 (1.3K) [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-filter-toggle.svg’
#
# mccourt.georgetown. 100%[===================>]   1.33K  --.-KB/s    in 0s
#
# 2021-04-27 14:11:21 (36.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-filter-toggle.svg’ saved [1357/1357]
#
# --2021-04-27 14:11:23--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-filter-toggle-close.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 522 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-filter-toggle-close.svg’
#
# mccourt.georgetown. 100%[===================>]     522  --.-KB/s    in 0s
#
# 2021-04-27 14:11:23 (13.0 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-filter-toggle-close.svg’ saved [522/522]
#
# --2021-04-27 14:11:25--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-hamburger-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 452 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-hamburger-white.svg’
#
# mccourt.georgetown. 100%[===================>]     452  --.-KB/s    in 0s
#
# 2021-04-27 14:11:25 (12.5 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-hamburger-white.svg’ saved [452/452]
#
# --2021-04-27 14:11:27--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-close.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 522 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-close.svg’
#
# mccourt.georgetown. 100%[===================>]     522  --.-KB/s    in 0s
#
# 2021-04-27 14:11:27 (14.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-close.svg’ saved [522/522]
#
# --2021-04-27 14:11:29--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-up-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 464 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-up-white.svg’
#
# mccourt.georgetown. 100%[===================>]     464  --.-KB/s    in 0s
#
# 2021-04-27 14:11:29 (9.33 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-up-white.svg’ saved [464/464]
#
# --2021-04-27 14:11:31--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-down-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 461 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-down-white.svg’
#
# mccourt.georgetown. 100%[===================>]     461  --.-KB/s    in 0s
#
# 2021-04-27 14:11:31 (13.4 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-down-white.svg’ saved [461/461]
#
# --2021-04-27 14:11:33--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-right.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 462 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-right.svg’
#
# mccourt.georgetown. 100%[===================>]     462  --.-KB/s    in 0s
#
# 2021-04-27 14:11:33 (11.6 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-right.svg’ saved [462/462]
#
# --2021-04-27 14:11:35--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-pause-carousel.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 405 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-pause-carousel.svg’
#
# mccourt.georgetown. 100%[===================>]     405  --.-KB/s    in 0s
#
# 2021-04-27 14:11:35 (9.67 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-pause-carousel.svg’ saved [405/405]
# --2021-04-27 14:11:37--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play-carousel.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 397 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play-carousel.svg’
#
# mccourt.georgetown. 100%[===================>]     397  --.-KB/s    in 0s
#
# 2021-04-27 14:11:37 (11.6 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/btn-play-carousel.svg’ saved [397/397]
#
# --2021-04-27 14:11:39--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-left.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 464 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-left.svg’
#
# mccourt.georgetown. 100%[===================>]     464  --.-KB/s    in 0s
#
# 2021-04-27 14:11:39 (13.6 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-left.svg’ saved [464/464]
#
# --2021-04-27 14:11:41--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/seal-georgetown-gray.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 237810 (232K) [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/seal-georgetown-gray.svg’
#
# mccourt.georgetown. 100%[===================>] 232.24K  --.-KB/s    in 0.002s
#
# 2021-04-27 14:11:41 (142 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/seal-georgetown-gray.svg’ saved [237810/237810]
#
# --2021-04-27 14:11:43--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/testimonialquote.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1189 (1.2K) [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/testimonialquote.svg’
#
# mccourt.georgetown. 100%[===================>]   1.16K  --.-KB/s    in 0s
#
# 2021-04-27 14:11:43 (32.7 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/testimonialquote.svg’ saved [1189/1189]
#
# --2021-04-27 14:11:45--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-right-white.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 462 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-right-white.svg’
#
# mccourt.georgetown. 100%[===================>]     462  --.-KB/s    in 0s
#
# 2021-04-27 14:11:45 (12.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrow-right-white.svg’ saved [462/462]
#
# --2021-04-27 14:11:47--  https://mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrowline.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 491 [image/svg+xml]
# Saving to: ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrowline.svg’
#
# mccourt.georgetown. 100%[===================>]     491  --.-KB/s    in 0s
#
# 2021-04-27 14:11:47 (11.3 MB/s) - ‘mccourt.georgetown.edu/wp-content/themes/georgetown/pattern_lab/source/images/icons/icon-arrowline.svg’ saved [491/491]
#
# --2021-04-27 14:11:49--  https://mccourt.georgetown.edu/images/icons/icon-close-blue.svg
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:11:50 ERROR 404: Not Found.
#
# FINISHED --2021-04-27 14:11:50--
# Total wall clock time: 1m 37s
# Downloaded: 47 files, 7.9M in 0.2s (43.8 MB/s)

# %% [markdown]
# ### Challenge
#
# Download only `.html` files from https://mccourt.georgetown.edu/research/ and links below that.

# %%
# Solution
# !wget --accept .html --recursive --no-parent --page-requisites --convert-links --wait=2 --tries=3 \
    --user-agent=Mozilla --header="Accept:text/html" --no-check-certificate \
    https://mccourt.georgetown.edu/research/
# Out:
# --2021-04-27 14:11:51--  https://mccourt.georgetown.edu/research/
# Resolving mccourt.georgetown.edu (mccourt.georgetown.edu)... 23.185.0.1, 2620:12a:8000::1, 2620:12a:8001::1
# Connecting to mccourt.georgetown.edu (mccourt.georgetown.edu)|23.185.0.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157616 (154K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/index.html’
#
# mccourt.georgetown. 100%[===================>] 153.92K  --.-KB/s    in 0.02s
#
# 2021-04-27 14:11:52 (7.32 MB/s) - ‘mccourt.georgetown.edu/research/index.html’ saved [157616/157616]
#
# Loading robots.txt; please ignore errors.
# --2021-04-27 14:11:54--  https://mccourt.georgetown.edu/robots.txt
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 116 [text/plain]
# Saving to: ‘mccourt.georgetown.edu/robots.txt.tmp’
#
# mccourt.georgetown. 100%[===================>]     116  --.-KB/s    in 0s
#
# 2021-04-27 14:11:54 (3.19 MB/s) - ‘mccourt.georgetown.edu/robots.txt.tmp’ saved [116/116]
#
# --2021-04-27 14:11:56--  https://mccourt.georgetown.edu/research/featured-publications/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 154027 (150K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/featured-publications/index.html’
#
# mccourt.georgetown. 100%[===================>] 150.42K  --.-KB/s    in 0.008s
#
# 2021-04-27 14:11:56 (18.4 MB/s) - ‘mccourt.georgetown.edu/research/featured-publications/index.html’ saved [154027/154027]
#
# --2021-04-27 14:11:58--  https://mccourt.georgetown.edu/research/mccourt-centers/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 145651 (142K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/mccourt-centers/index.html’
#
# mccourt.georgetown. 100%[===================>] 142.24K  --.-KB/s    in 0.003s
#
# 2021-04-27 14:11:59 (44.2 MB/s) - ‘mccourt.georgetown.edu/research/mccourt-centers/index.html’ saved [145651/145651]
#
# --2021-04-27 14:12:01--  https://mccourt.georgetown.edu/research/research-data-center/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 139956 (137K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/index.html’
#
# mccourt.georgetown. 100%[===================>] 136.68K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:01 (32.5 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/index.html’ saved [139956/139956]
#
# --2021-04-27 14:12:03--  https://mccourt.georgetown.edu/research/the-massive-data-institute/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 155732 (152K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/index.html’
#
# mccourt.georgetown. 100%[===================>] 152.08K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:04 (149 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/index.html’ saved [155732/155732]
#
# --2021-04-27 14:12:06--  https://mccourt.georgetown.edu/research/faculty-seminars/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 157026 (153K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/faculty-seminars/index.html’
#
# mccourt.georgetown. 100%[===================>] 153.35K  --.-KB/s    in 0.005s
#
# 2021-04-27 14:12:08 (28.0 MB/s) - ‘mccourt.georgetown.edu/research/faculty-seminars/index.html’ saved [157026/157026]
#
# --2021-04-27 14:12:10--  https://mccourt.georgetown.edu/research/mccourt-centers/research-center-directors/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 155073 (151K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/mccourt-centers/research-center-directors/index.html’
#
# mccourt.georgetown. 100%[===================>] 151.44K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:10 (33.8 MB/s) - ‘mccourt.georgetown.edu/research/mccourt-centers/research-center-directors/index.html’ saved [155073/155073]
#
# --2021-04-27 14:12:12--  https://mccourt.georgetown.edu/research/mdi-news/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 148325 (145K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/mdi-news/index.html’
#
# mccourt.georgetown. 100%[===================>] 144.85K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:12 (36.1 MB/s) - ‘mccourt.georgetown.edu/research/mdi-news/index.html’ saved [148325/148325]
#
# --2021-04-27 14:12:14--  https://mccourt.georgetown.edu/research/the-massive-data-institute/resources/dp-resources/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143363 (140K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/resources/dp-resources/index.html’
#
# mccourt.georgetown. 100%[===================>] 140.00K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:15 (33.0 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/resources/dp-resources/index.html’ saved [143363/143363]
#
# --2021-04-27 14:12:17--  https://mccourt.georgetown.edu/research/research-data-center/getting-started/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144786 (141K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/getting-started/index.html’
#
# mccourt.georgetown. 100%[===================>] 141.39K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:17 (32.6 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/getting-started/index.html’ saved [144786/144786]
#
# --2021-04-27 14:12:19--  https://mccourt.georgetown.edu/research/research-data-center/administrative-data-metadata/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 139980 (137K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/administrative-data-metadata/index.html’
#
# mccourt.georgetown. 100%[===================>] 136.70K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:19 (33.8 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/administrative-data-metadata/index.html’ saved [139980/139980]
#
# --2021-04-27 14:12:21--  https://mccourt.georgetown.edu/research/research-data-center/research/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 140145 (137K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/research/index.html’
#
# mccourt.georgetown. 100%[===================>] 136.86K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:22 (31.1 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/research/index.html’ saved [140145/140145]
#
# --2021-04-27 14:12:24--  https://mccourt.georgetown.edu/research/research-data-center/data-and-software-available/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 156464 (153K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/data-and-software-available/index.html’
#
# mccourt.georgetown. 100%[===================>] 152.80K  --.-KB/s    in 0.005s
#
# 2021-04-27 14:12:24 (33.1 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/data-and-software-available/index.html’ saved [156464/156464]
#
# --2021-04-27 14:12:26--  https://mccourt.georgetown.edu/research/research-data-center/contact-us/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 137306 (134K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/contact-us/index.html’
#
# mccourt.georgetown. 100%[===================>] 134.09K  --.-KB/s    in 0.004s
#
# 2021-04-27 14:12:27 (32.7 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/contact-us/index.html’ saved [137306/137306]
#
# --2021-04-27 14:12:29--  https://mccourt.georgetown.edu/research/the-massive-data-institute/supporting-ethical-data-governance/research-data-center/contact-us/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:12:29 ERROR 404: Not Found.
#
# --2021-04-27 14:12:31--  https://mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/
# Connecting to mccourt.georgetown.edu (mccourt.georgetown.edu)|23.185.0.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143331 (140K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/index.html’
#
# mccourt.georgetown. 100%[===================>] 139.97K  --.-KB/s    in 0.02s
#
# 2021-04-27 14:12:32 (8.55 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/index.html’ saved [143331/143331]
#
# --2021-04-27 14:12:34--  https://mccourt.georgetown.edu/research/the-massive-data-institute/shape-the-policy-conversation/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142753 (139K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/shape-the-policy-conversation/index.html’
#
# mccourt.georgetown. 100%[===================>] 139.41K  --.-KB/s    in 0.008s
#
# 2021-04-27 14:12:35 (18.1 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/shape-the-policy-conversation/index.html’ saved [142753/142753]
#
# --2021-04-27 14:12:37--  https://mccourt.georgetown.edu/research/the-massive-data-institute/improving-data-driven-policy-making/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143621 (140K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/improving-data-driven-policy-making/index.html’
#
# mccourt.georgetown. 100%[===================>] 140.25K  --.-KB/s    in 0.002s
#
# 2021-04-27 14:12:37 (81.9 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/improving-data-driven-policy-making/index.html’ saved [143621/143621]
#
# --2021-04-27 14:12:39--  https://mccourt.georgetown.edu/research/the-massive-data-institute/about-mdi/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143501 (140K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/about-mdi/index.html’
#
# mccourt.georgetown. 100%[===================>] 140.14K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:39 (152 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/about-mdi/index.html’ saved [143501/143501]
#
# --2021-04-27 14:12:41--  https://mccourt.georgetown.edu/research/the-massive-data-institute/funding-opportunities/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 152029 (148K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/funding-opportunities/index.html’
#
# mccourt.georgetown. 100%[===================>] 148.47K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:42 (158 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/funding-opportunities/index.html’ saved [152029/152029]
#
# --2021-04-27 14:12:44--  https://mccourt.georgetown.edu/research/the-massive-data-institute/compute-infrastructure/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143447 (140K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/compute-infrastructure/index.html’
#
# mccourt.georgetown. 100%[===================>] 140.08K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:44 (143 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/compute-infrastructure/index.html’ saved [143447/143447]
#
# --2021-04-27 14:12:46--  https://mccourt.georgetown.edu/research/the-massive-data-institute/resources/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142043 (139K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/resources/index.html’
#
# mccourt.georgetown. 100%[===================>] 138.71K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:46 (115 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/resources/index.html’ saved [142043/142043]
#
# --2021-04-27 14:12:48--  https://mccourt.georgetown.edu/research/the-massive-data-institute/mdi-data-blending/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 141487 (138K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-data-blending/index.html’
#
# mccourt.georgetown. 100%[===================>] 138.17K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:49 (139 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-data-blending/index.html’ saved [141487/141487]
#
# --2021-04-27 14:12:51--  https://mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research-and-collaborations/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 147895 (144K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research-and-collaborations/index.html’
#
# mccourt.georgetown. 100%[===================>] 144.43K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:51 (147 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research-and-collaborations/index.html’ saved [147895/147895]
#
# --2021-04-27 14:12:53--  https://mccourt.georgetown.edu/research/the-massive-data-institute/mdi-conferences-and-panels/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 149002 (146K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-conferences-and-panels/index.html’
#
# mccourt.georgetown. 100%[===================>] 145.51K  --.-KB/s    in 0.001s
#
# 2021-04-27 14:12:54 (164 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-conferences-and-panels/index.html’ saved [149002/149002]
#
# FINISHED --2021-04-27 14:12:54--
# Total wall clock time: 1m 3s
# Downloaded: 25 files, 3.4M in 0.1s (31.3 MB/s)
# Converting links in mccourt.georgetown.edu/research/mdi-news/index.html... 17-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/administrative-data-metadata/index.html... 28-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/index.html... 35-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research-and-collaborations/index.html... 32-8
# Converting links in mccourt.georgetown.edu/research/index.html... 20-12
# Converting links in mccourt.georgetown.edu/research/research-data-center/research/index.html... 28-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/improving-data-driven-policy-making/index.html... 32-10
# Converting links in mccourt.georgetown.edu/research/research-data-center/index.html... 33-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/getting-started/index.html... 28-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/mdi-data-blending/index.html... 31-8
# Converting links in mccourt.georgetown.edu/research/featured-publications/index.html... 17-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/shape-the-policy-conversation/index.html... 32-8
# Converting links in mccourt.georgetown.edu/research/mccourt-centers/research-center-directors/index.html... 17-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/contact-us/index.html... 28-8
# Converting links in mccourt.georgetown.edu/research/faculty-seminars/index.html... 33-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/data-and-software-available/index.html... 28-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/about-mdi/index.html... 24-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/funding-opportunities/index.html... 35-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/index.html... 24-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/compute-infrastructure/index.html... 32-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/resources/dp-resources/index.html... 23-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/resources/index.html... 34-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/mdi-conferences-and-panels/index.html... 32-8
# Converting links in mccourt.georgetown.edu/research/mccourt-centers/index.html... 24-8
# Converted links in 24 files in 0.07 seconds.

# %% [markdown]
# ### Challenge
#
# Use advanced options for `wget` (listed above) to mirror a website you use often. Be sure to use a polite `--wait` and avoid downloading anything with massive numbers of links, files, or pages (e.g., don't try YouTube.com or Wikipedia.com). If you want to download a segment or specific page within a website (e.g., a single YouTube channel or Wikipedia page), use the `--recursive` option with `--no-parent` (to follow only links within the input URL).
#
# While you let `wget` run, read more about it on its [manual](https://www.gnu.org/software/wget/manual/wget.html) and see other examples of `wget` usage [here](https://gist.github.com/bueckl/bd0a1e7a30bc8e2eeefd) and [here](https://phoenixnap.com/kb/wget-command-with-examples).

# %%
# Solution
# !wget --mirror --recursive --no-parent --page-requisites --convert-links --wait=2 --tries=3 \
    --user-agent=Mozilla --header="Accept:text/html" --no-check-certificate \
    https://www.jarenhaber.com/
# Out:
# --2021-04-27 14:12:55--  https://www.jarenhaber.com/
# Resolving www.jarenhaber.com (www.jarenhaber.com)... 52.73.153.209, 54.205.240.192, 2604:a880:400:d0::1756:9001, ...
# Connecting to www.jarenhaber.com (www.jarenhaber.com)|52.73.153.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/index.html’
#
# www.jarenhaber.com/     [ <=>                ]  21.41K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:12:55 (730 KB/s) - ‘www.jarenhaber.com/index.html’ saved [21928]
#
# Loading robots.txt; please ignore errors.
# --2021-04-27 14:12:57--  https://www.jarenhaber.com/robots.txt
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:12:57 ERROR 404: Not Found.
#
# --2021-04-27 14:12:59--  https://www.jarenhaber.com/css/academic.min.ccb935070d24cc8b4be2d0c581d1f687.css
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 171107 (167K) [text/css]
# Saving to: ‘www.jarenhaber.com/css/academic.min.ccb935070d24cc8b4be2d0c581d1f687.css’
#
# www.jarenhaber.com/ 100%[===================>] 167.10K  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:12:59 (1.58 MB/s) - ‘www.jarenhaber.com/css/academic.min.ccb935070d24cc8b4be2d0c581d1f687.css’ saved [171107/171107]
#
# --2021-04-27 14:13:01--  https://www.jarenhaber.com/index.xml
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2287 (2.2K) [application/xml]
# Saving to: ‘www.jarenhaber.com/index.xml’
#
# www.jarenhaber.com/ 100%[===================>]   2.23K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:02 (62.5 MB/s) - ‘www.jarenhaber.com/index.xml’ saved [2287/2287]
#
# --2021-04-27 14:13:04--  https://www.jarenhaber.com/site.webmanifest
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 285 [application/octet-stream]
# Saving to: ‘www.jarenhaber.com/site.webmanifest’
#
# www.jarenhaber.com/ 100%[===================>]     285  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:04 (3.50 MB/s) - ‘www.jarenhaber.com/site.webmanifest’ saved [285/285]
#
# --2021-04-27 14:13:06--  https://www.jarenhaber.com/img/icon.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 31813 (31K) [image/png]
# Saving to: ‘www.jarenhaber.com/img/icon.png’
#
# www.jarenhaber.com/ 100%[===================>]  31.07K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:06 (1.13 MB/s) - ‘www.jarenhaber.com/img/icon.png’ saved [31813/31813]
#
# --2021-04-27 14:13:08--  https://www.jarenhaber.com/img/icon-192.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 31813 (31K) [image/png]
# Saving to: ‘www.jarenhaber.com/img/icon-192.png’
#
# www.jarenhaber.com/ 100%[===================>]  31.07K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:08 (1.12 MB/s) - ‘www.jarenhaber.com/img/icon-192.png’ saved [31813/31813]
#
# --2021-04-27 14:13:10--  https://www.jarenhaber.com/files/CV_Haber.pdf
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 168817 (165K) [application/pdf]
# Saving to: ‘www.jarenhaber.com/files/CV_Haber.pdf’
#
# www.jarenhaber.com/ 100%[===================>] 164.86K  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:10 (1.58 MB/s) - ‘www.jarenhaber.com/files/CV_Haber.pdf’ saved [168817/168817]
#
# --2021-04-27 14:13:12--  https://www.jarenhaber.com/authors/admin/avatar_hu3f0121846b56c87492f2875c444c15be_1065540_250x250_fill_q100_lanczos_center.jpg
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 45315 (44K) [image/jpeg]
# Saving to: ‘www.jarenhaber.com/authors/admin/avatar_hu3f0121846b56c87492f2875c444c15be_1065540_250x250_fill_q100_lanczos_center.jpg’
#
# www.jarenhaber.com/ 100%[===================>]  44.25K  --.-KB/s    in 0.05s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:12 (847 KB/s) - ‘www.jarenhaber.com/authors/admin/avatar_hu3f0121846b56c87492f2875c444c15be_1065540_250x250_fill_q100_lanczos_center.jpg’ saved [45315/45315]
#
# --2021-04-27 14:13:14--  https://www.jarenhaber.com/href
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:13:14 ERROR 404: Not Found.
#
# --2021-04-27 14:13:16--  https://www.jarenhaber.com/publication/institutionalized-involvement/
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/publication/institutionalized-involvement/index.html’
#
# www.jarenhaber.com/     [ <=>                ]  16.55K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:17 (575 KB/s) - ‘www.jarenhaber.com/publication/institutionalized-involvement/index.html’ saved [16945]
#
# --2021-04-27 14:13:19--  https://www.jarenhaber.com/authors/admin/
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/authors/admin/index.html’
#
# www.jarenhaber.com/     [ <=>                ]  10.68K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:19 (78.0 MB/s) - ‘www.jarenhaber.com/authors/admin/index.html’ saved [10935]
#
# --2021-04-27 14:13:21--  https://www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_150x0_resize_q100_lanczos.jpg
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4306 (4.2K) [image/jpeg]
# Saving to: ‘www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_150x0_resize_q100_lanczos.jpg’
#
# www.jarenhaber.com/ 100%[===================>]   4.21K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:21 (116 MB/s) - ‘www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_150x0_resize_q100_lanczos.jpg’ saved [4306/4306]
#
# --2021-04-27 14:13:23--  https://www.jarenhaber.com/talk/selling-segregation/
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/talk/selling-segregation/index.html’
#
# www.jarenhaber.com/     [ <=>                ]  17.37K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:23 (606 KB/s) - ‘www.jarenhaber.com/talk/selling-segregation/index.html’ saved [17785]
#
# --2021-04-27 14:13:25--  https://www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_150x0_resize_lanczos_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3656 (3.6K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_150x0_resize_lanczos_2.png’
#
# www.jarenhaber.com/ 100%[===================>]   3.57K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:25 (88.6 MB/s) - ‘www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_150x0_resize_lanczos_2.png’ saved [3656/3656]
#
# --2021-04-27 14:13:27--  https://www.jarenhaber.com/talk/sorting-schools/
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/talk/sorting-schools/index.html’
#
# www.jarenhaber.com/     [ <=>                ]  17.43K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:28 (666 KB/s) - ‘www.jarenhaber.com/talk/sorting-schools/index.html’ saved [17852]
# --2021-04-27 14:13:30--  https://www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_150x0_resize_lanczos_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14322 (14K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_150x0_resize_lanczos_2.png’
#
# www.jarenhaber.com/ 100%[===================>]  13.99K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:30 (551 KB/s) - ‘www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_150x0_resize_lanczos_2.png’ saved [14322/14322]
#
# --2021-04-27 14:13:32--  https://www.jarenhaber.com/talk/dictionaries/
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/talk/dictionaries/index.html’
#
# www.jarenhaber.com/     [ <=>                ]  17.99K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:32 (615 KB/s) - ‘www.jarenhaber.com/talk/dictionaries/index.html’ saved [18419]
#
# --2021-04-27 14:13:34--  https://www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_150x0_resize_lanczos_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19411 (19K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_150x0_resize_lanczos_2.png’
#
# www.jarenhaber.com/ 100%[===================>]  18.96K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:34 (731 KB/s) - ‘www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_150x0_resize_lanczos_2.png’ saved [19411/19411]
#
# --2021-04-27 14:13:36--  https://www.jarenhaber.com/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:13:36 ERROR 404: Not Found.
#
# --2021-04-27 14:13:39--  https://www.jarenhaber.com/js/academic.min.174c04eddb854712a9c7aaae9021446f.js
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70868 (69K) [application/javascript]
# Saving to: ‘www.jarenhaber.com/js/academic.min.174c04eddb854712a9c7aaae9021446f.js’
#
# www.jarenhaber.com/ 100%[===================>]  69.21K  --.-KB/s    in 0.05s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:39 (1.24 MB/s) - ‘www.jarenhaber.com/js/academic.min.174c04eddb854712a9c7aaae9021446f.js’ saved [70868/70868]
#
# --2021-04-27 14:13:41--  https://www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_800x0_resize_q100_lanczos.jpg
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 53530 (52K) [image/jpeg]
# Saving to: ‘www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_800x0_resize_q100_lanczos.jpg’
#
# www.jarenhaber.com/ 100%[===================>]  52.28K  --.-KB/s    in 0.08s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:41 (640 KB/s) - ‘www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_800x0_resize_q100_lanczos.jpg’ saved [53530/53530]
#
# --2021-04-27 14:13:43--  https://www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_680x500_fill_q90_lanczos_smart1.jpg
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 37641 (37K) [image/jpeg]
# Saving to: ‘www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_680x500_fill_q90_lanczos_smart1.jpg’
#
# www.jarenhaber.com/ 100%[===================>]  36.76K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:43 (1.33 MB/s) - ‘www.jarenhaber.com/publication/institutionalized-involvement/featured_huafe34a395a14badd2a4dfcefaae88856_231774_680x500_fill_q90_lanczos_smart1.jpg’ saved [37641/37641]
#
# --2021-04-27 14:13:45--  https://www.jarenhaber.com/publication/
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘www.jarenhaber.com/publication/index.html’
#
# www.jarenhaber.com/     [ <=>                ]   9.00K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:46 (53.9 MB/s) - ‘www.jarenhaber.com/publication/index.html’ saved [9214]
#
# --2021-04-27 14:13:48--  https://www.jarenhaber.com/publication/institutionalized-involvement/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:13:48 ERROR 404: Not Found.
#
# --2021-04-27 14:13:50--  https://www.jarenhaber.com/authors/admin/index.xml
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2480 (2.4K) [application/xml]
# Saving to: ‘www.jarenhaber.com/authors/admin/index.xml’
#
# www.jarenhaber.com/ 100%[===================>]   2.42K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:50 (60.3 MB/s) - ‘www.jarenhaber.com/authors/admin/index.xml’ saved [2480/2480]
#
# --2021-04-27 14:13:52--  https://www.jarenhaber.com/authors/admin/href
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:13:52 ERROR 404: Not Found.
#
# --2021-04-27 14:13:54--  https://www.jarenhaber.com/authors/admin/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:13:54 ERROR 404: Not Found.
#
# --2021-04-27 14:13:56--  https://www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_800x0_resize_lanczos_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 37430 (37K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_800x0_resize_lanczos_2.png’
#
# www.jarenhaber.com/ 100%[===================>]  36.55K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:57 (1.34 MB/s) - ‘www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_800x0_resize_lanczos_2.png’ saved [37430/37430]
#
# --2021-04-27 14:13:59--  https://www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_680x500_fill_q90_lanczos_right_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 40491 (40K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_680x500_fill_q90_lanczos_right_2.png’
#
# www.jarenhaber.com/ 100%[===================>]  39.54K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:13:59 (1.38 MB/s) - ‘www.jarenhaber.com/talk/selling-segregation/featured_hu4c14fbdee759c111b7b4d8f5931748e7_269559_680x500_fill_q90_lanczos_right_2.png’ saved [40491/40491]
#
# --2021-04-27 14:14:01--  https://www.jarenhaber.com/js/mathjax-config.js
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 329 [application/javascript]
# Saving to: ‘www.jarenhaber.com/js/mathjax-config.js’
#
# www.jarenhaber.com/ 100%[===================>]     329  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:14:01 (9.34 MB/s) - ‘www.jarenhaber.com/js/mathjax-config.js’ saved [329/329]
#
# --2021-04-27 14:14:03--  https://www.jarenhaber.com/talk/selling-segregation/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:14:03 ERROR 404: Not Found.
#
# --2021-04-27 14:14:05--  https://www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_800x0_resize_lanczos_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 181862 (178K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_800x0_resize_lanczos_2.png’
#
# www.jarenhaber.com/ 100%[===================>] 177.60K  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:14:05 (1.47 MB/s) - ‘www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_800x0_resize_lanczos_2.png’ saved [181862/181862]
#
# --2021-04-27 14:14:07--  https://www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_680x500_fill_q90_lanczos_right_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126399 (123K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_680x500_fill_q90_lanczos_right_2.png’
#
# www.jarenhaber.com/ 100%[===================>] 123.44K  --.-KB/s    in 0.08s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:14:07 (1.44 MB/s) - ‘www.jarenhaber.com/talk/sorting-schools/featured_hu4a598c5d9d41a801e0d33745df71852e_394678_680x500_fill_q90_lanczos_right_2.png’ saved [126399/126399]
#
# --2021-04-27 14:14:09--  https://www.jarenhaber.com/talk/sorting-schools/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:14:10 ERROR 404: Not Found.
#
# --2021-04-27 14:14:12--  https://www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_800x0_resize_lanczos_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 189242 (185K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_800x0_resize_lanczos_2.png’
#
# www.jarenhaber.com/ 100%[===================>] 184.81K  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:14:12 (1.53 MB/s) - ‘www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_800x0_resize_lanczos_2.png’ saved [189242/189242]
#
# --2021-04-27 14:14:14--  https://www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_680x500_fill_q90_lanczos_right_2.png
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 153697 (150K) [image/png]
# Saving to: ‘www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_680x500_fill_q90_lanczos_right_2.png’
#
# www.jarenhaber.com/ 100%[===================>] 150.09K  --.-KB/s    in 0.1s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:14:14 (1.27 MB/s) - ‘www.jarenhaber.com/talk/dictionaries/featured_hu5aab59663c34ff8296f55d394e5eb904_81646_680x500_fill_q90_lanczos_right_2.png’ saved [153697/153697]
#
# --2021-04-27 14:14:16--  https://www.jarenhaber.com/talk/dictionaries/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:14:17 ERROR 404: Not Found.
#
# --2021-04-27 14:14:19--  https://www.jarenhaber.com/publication/index.xml
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 843 [application/xml]
# Saving to: ‘www.jarenhaber.com/publication/index.xml’
#
# www.jarenhaber.com/ 100%[===================>]     843  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-04-27 14:14:19 (21.8 MB/s) - ‘www.jarenhaber.com/publication/index.xml’ saved [843/843]
#
# --2021-04-27 14:14:21--  https://www.jarenhaber.com/publication/%7B%7Brelpermalink%7D%7D
# Reusing existing connection to www.jarenhaber.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-04-27 14:14:21 ERROR 404: Not Found.
#
# FINISHED --2021-04-27 14:14:21--
# Total wall clock time: 1m 26s
# Downloaded: 30 files, 1.4M in 1.2s (1.24 MB/s)
# Converting links in www.jarenhaber.com/talk/sorting-schools/index.html... 27-2
# Converting links in www.jarenhaber.com/publication/institutionalized-involvement/index.html... 29-2
# Converting links in www.jarenhaber.com/talk/dictionaries/index.html... 27-2
# Converting links in www.jarenhaber.com/publication/index.html... 25-2
# Converting links in www.jarenhaber.com/talk/selling-segregation/index.html... 27-2
# Converting links in www.jarenhaber.com/index.html... 38-3
# Converting links in www.jarenhaber.com/authors/admin/index.html... 26-3
# Converting links in www.jarenhaber.com/css/academic.min.ccb935070d24cc8b4be2d0c581d1f687.css... nothing to do.
# Converted links in 8 files in 0.01 seconds.
